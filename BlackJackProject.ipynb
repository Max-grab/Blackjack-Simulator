# %%
import random
deck =(2,3,4,5,6,7,8,9,10,10,10,10,11) 
dealer_hand = []
user_hand = []

user_hand.append(random.choose(deck))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 6
#       3 dealer_hand = []
#       4 user_hand = []
# ----> 6 user_hand.append(random.choose(deck))
#
# AttributeError: module 'random' has no attribute 'choose'
